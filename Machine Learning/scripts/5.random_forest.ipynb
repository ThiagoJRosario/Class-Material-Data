# %%
# Algoritmo Random Forest

# %%
# Importação das bibliotecas
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.ensemble import RandomForestClassifier

# %%
# Carregamento da base de dados e criação dos previsores (variáveis independentes - X) e da classe (variável dependente - y)
credito = pd.read_csv(r'C:\Users\thiag\Desktop\Programação\Data Science\Curso DS\MaterialAula\31.Prática em Python\dados\Credit.csv')
credito.head()
# Out:
#   checking_status  duration                    credit_history  \
# 0              <0         6  'critical/other existing credit'
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
# 4              <0        24              'delayed previously'
#
#                purpose  credit_amount      savings_status employment  \
# 0             radio/tv           1169  'no known savings'        >=7
# 1             radio/tv           5951                <100     1<=X<4
# 2            education           2096                <100     4<=X<7
# 3  furniture/equipment           7882                <100     4<=X<7
# 4            'new car'           4870                <100     1<=X<4
#
#    installment_commitment       personal_status other_parties  ...  \
# 0                       4         'male single'          none  ...
# 1                       2  'female div/dep/mar'          none  ...
# 2                       2         'male single'          none  ...
# 3                       2         'male single'     guarantor  ...
# 4                       3         'male single'          none  ...
#
#     property_magnitude age  other_payment_plans     housing existing_credits  \
# 0        'real estate'  67                 none         own                2
# 1        'real estate'  22                 none         own                1
# 2        'real estate'  49                 none         own                1
# 3     'life insurance'  45                 none  'for free'                1
# 4  'no known property'  53                 none  'for free'                2
#
#                     job num_dependents  own_telephone foreign_worker class
# 0               skilled              1            yes            yes  good
# 1               skilled              1           none            yes   bad
# 2  'unskilled resident'              2           none            yes  good
# 3               skilled              2           none            yes  good
# 4               skilled              2           none            yes   bad
#
# [5 rows x 21 columns]

# %%
previsores = credito.iloc[:,0:20].values
classe = credito.iloc[:,20].values

# %%
# Transformação dos atributos categóricos em atributos numéricos, passando o índice de cada atributo categórico
labelencoder = LabelEncoder()
previsores[:,0] = labelencoder.fit_transform(previsores[:,0])
previsores[:,2] = labelencoder.fit_transform(previsores[:,2])
previsores[:, 3] = labelencoder.fit_transform(previsores[:, 3])
previsores[:, 5] = labelencoder.fit_transform(previsores[:, 5])
previsores[:, 6] = labelencoder.fit_transform(previsores[:, 6])
previsores[:, 8] = labelencoder.fit_transform(previsores[:, 8])
previsores[:, 9] = labelencoder.fit_transform(previsores[:, 9])
previsores[:, 11] = labelencoder.fit_transform(previsores[:, 11])
previsores[:, 13] = labelencoder.fit_transform(previsores[:, 13])
previsores[:, 14] = labelencoder.fit_transform(previsores[:, 14])
previsores[:, 16] = labelencoder.fit_transform(previsores[:, 16])
previsores[:, 18] = labelencoder.fit_transform(previsores[:, 18])
previsores[:, 19] = labelencoder.fit_transform(previsores[:, 19])

# %%
# Divisão da base de dados entre treinamento e teste (30% para testar e 70% para treinar)
X_treinamento, X_teste, y_treinamento, y_teste = train_test_split(previsores,
                                                                  classe,
                                                                  test_size = 0.3,
                                                                  random_state = 0)

# %%
# Criação do modelo, treinamento, obtenção das previsões e da taxa de acerto
floresta = RandomForestClassifier(n_estimators = 100)
floresta.fit(X_treinamento, y_treinamento)
# Out:
# RandomForestClassifier()

# %%
# Visualização dos atributos principais
floresta.estimators_
#floresta.estimators_[1]
# Out:
# [DecisionTreeClassifier(max_features='sqrt', random_state=1213698472),
#  DecisionTreeClassifier(max_features='sqrt', random_state=573563470),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1726651305),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1692316920),
#  DecisionTreeClassifier(max_features='sqrt', random_state=72192804),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1052313636),
#  DecisionTreeClassifier(max_features='sqrt', random_state=791195008),
#  DecisionTreeClassifier(max_features='sqrt', random_state=443704961),
#  DecisionTreeClassifier(max_features='sqrt', random_state=906340302),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1249263505),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1184982898),
#  DecisionTreeClassifier(max_features='sqrt', random_state=912869755),
#  DecisionTreeClassifier(max_features='sqrt', random_state=677806382),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1910046397),
#  DecisionTreeClassifier(max_features='sqrt', random_state=406189191),
#  DecisionTreeClassifier(max_features='sqrt', random_state=576835964),
#  DecisionTreeClassifier(max_features='sqrt', random_state=335367255),
#  DecisionTreeClassifier(max_features='sqrt', random_state=847633547),
#  DecisionTreeClassifier(max_features='sqrt', random_state=946483334),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1829678821),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1928029463),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1035580563),
#  DecisionTreeClassifier(max_features='sqrt', random_state=206354961),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1487722051),
#  DecisionTreeClassifier(max_features='sqrt', random_state=710858696),
#  DecisionTreeClassifier(max_features='sqrt', random_state=889007293),
#  DecisionTreeClassifier(max_features='sqrt', random_state=414981885),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1138679997),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2024294832),
#  DecisionTreeClassifier(max_features='sqrt', random_state=55485054),
#  DecisionTreeClassifier(max_features='sqrt', random_state=387963780),
#  DecisionTreeClassifier(max_features='sqrt', random_state=926278242),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1861748301),
#  DecisionTreeClassifier(max_features='sqrt', random_state=819617856),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1458542419),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2060732987),
#  DecisionTreeClassifier(max_features='sqrt', random_state=181866812),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2089799858),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1427768201),
#  DecisionTreeClassifier(max_features='sqrt', random_state=635061911),
#  DecisionTreeClassifier(max_features='sqrt', random_state=910535056),
#  DecisionTreeClassifier(max_features='sqrt', random_state=178247040),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1738752910),
#  DecisionTreeClassifier(max_features='sqrt', random_state=946338396),
#  DecisionTreeClassifier(max_features='sqrt', random_state=378324693),
#  DecisionTreeClassifier(max_features='sqrt', random_state=268292016),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1704959842),
#  DecisionTreeClassifier(max_features='sqrt', random_state=657934876),
#  DecisionTreeClassifier(max_features='sqrt', random_state=888020683),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1719569941),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1165920461),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1249304107),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1449042261),
#  DecisionTreeClassifier(max_features='sqrt', random_state=765082777),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1461325706),
#  DecisionTreeClassifier(max_features='sqrt', random_state=473076244),
#  DecisionTreeClassifier(max_features='sqrt', random_state=768566178),
#  DecisionTreeClassifier(max_features='sqrt', random_state=658897755),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1965179011),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1939222759),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2131919996),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1487158965),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1421227666),
#  DecisionTreeClassifier(max_features='sqrt', random_state=112213797),
#  DecisionTreeClassifier(max_features='sqrt', random_state=131706139),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1460696800),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1687837232),
#  DecisionTreeClassifier(max_features='sqrt', random_state=852656245),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1072494077),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1920180881),
#  DecisionTreeClassifier(max_features='sqrt', random_state=727097709),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1755014792),
#  DecisionTreeClassifier(max_features='sqrt', random_state=864180611),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1219689585),
#  DecisionTreeClassifier(max_features='sqrt', random_state=110562207),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1522184041),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1661922851),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1728130666),
#  DecisionTreeClassifier(max_features='sqrt', random_state=370768171),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1306060001),
#  DecisionTreeClassifier(max_features='sqrt', random_state=471506657),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1327786766),
#  DecisionTreeClassifier(max_features='sqrt', random_state=937600910),
#  DecisionTreeClassifier(max_features='sqrt', random_state=972390515),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1022169638),
#  DecisionTreeClassifier(max_features='sqrt', random_state=666981920),
#  DecisionTreeClassifier(max_features='sqrt', random_state=705693179),
#  DecisionTreeClassifier(max_features='sqrt', random_state=419168122),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2109422139),
#  DecisionTreeClassifier(max_features='sqrt', random_state=207681487),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1293336961),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2029454772),
#  DecisionTreeClassifier(max_features='sqrt', random_state=143499414),
#  DecisionTreeClassifier(max_features='sqrt', random_state=796924243),
#  DecisionTreeClassifier(max_features='sqrt', random_state=639673839),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1633181023),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1851692598),
#  DecisionTreeClassifier(max_features='sqrt', random_state=600857582),
#  DecisionTreeClassifier(max_features='sqrt', random_state=779259285),
#  DecisionTreeClassifier(max_features='sqrt', random_state=137267321)]

# %%
previsoes = floresta.predict(X_teste)
confusao = confusion_matrix(y_teste, previsoes)
taxa_acerto = accuracy_score(y_teste, previsoes)
taxa_acerto
# Out:
# 0.78
